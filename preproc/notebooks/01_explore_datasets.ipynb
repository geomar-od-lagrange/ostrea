# %% [markdown]
# # Explore connectivity datasets
#
# Opens all 9 NetCDF files via OPeNDAP (THREDDS) and displays their structure.

# %%
import xarray as xr

BASE = (
    "https://data.geomar.de/thredds/dodsC/"
    "20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb23190/submission"
)

files = [
    ("05m", "00-07days"),
    ("05m", "07-14days"),
    ("05m", "07-28days"),
    ("10m", "00-07days"),
    ("10m", "07-14days"),
    ("10m", "07-28days"),
    ("15m", "00-07days"),
    ("15m", "07-14days"),
    ("15m", "07-28days"),
]

def opendap_url(depth, time):
    name = f"040_connectivity_analysis_{depth}_{time}.nc"
    return f"{BASE}/040_connectivity_analysis_{depth}/{name}"

# %%
for depth, time in files:
    url = opendap_url(depth, time)
    print(f"\n{'='*60}")
    print(f"depth={depth}  time={time}")
    print(url)
    print('='*60)
    ds = xr.open_dataset(url, engine="netcdf4")
    display(ds)
# Out:
# ============================================================
# depth=05m  time=00-07days
# https://data.geomar.de/thredds/dodsC/20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb23190/submission/040_connectivity_analysis_05m/040_connectivity_analysis_05m_00-07days.nc
# ============================================================
# <xarray.Dataset> Size: 11GB
# Dimensions:              (hex0: 8364, hex1: 8397, corner: 7, month: 5, year: 4)
# Coordinates:
#   * hex0                 (hex0) |S64 535kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex0             (hex0) float64 67kB ...
#     lat_hex0             (hex0) float64 67kB ...
#     hex_label            (hex0) |S64 535kB ...
#   * hex1                 (hex1) |S64 537kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex1             (hex1) float64 67kB ...
#     lat_hex1             (hex1) float64 67kB ...
#   * month                (month) float64 40B 0.0 1.0 2.0 3.0 4.0
#   * year                 (year) float64 32B 0.0 1.0 2.0 3.0
# Dimensions without coordinates: corner
# Data variables: (12/29)
#     aqc_count_hex0       (hex0) float64 67kB ...
#     rst_count_hex0       (hex0) float64 67kB ...
#     pop_count_hex0       (hex0) float64 67kB ...
#     dss_count_hex0       (hex0) float64 67kB ...
#     hly_count_hex0       (hex0) float64 67kB ...
#     his_count_hex0       (hex0) float64 67kB ...
#     ...                   ...
#     depth_std_hex1       (hex1) float32 34kB ...
#     lon_hex0_corners     (corner, hex0) float64 468kB ...
#     lat_hex0_corners     (corner, hex0) float64 468kB ...
#     lon_hex1_corners     (corner, hex1) float64 470kB ...
#     lat_hex1_corners     (corner, hex1) float64 470kB ...
#     obs                  (month, year, hex0, hex1) float64 11GB ...
# Attributes: (12/35)
#     date_created:            2025-09-04
#     date_issued:             2025-09-05
#     date_metadata_modified:  2025-09-05
#     creator_name:            Lara Schmittmann
#     creator_email:           lschmittmann@geomar.de
#     creator_id:              https://orcid.org/0009-0008-8302-6607
#     ...                      ...
#     source:                  Simulated Lagrangian particle trajectories (Ocea...
#     Conventions:             CF-1.8
#     NCO:                     netCDF Operators version 5.1.5 (Homepage = http:...
#     history:                 Fri Sep  5 17:13:58 2025: ncatted -O -a history,...
#     id:                      hdl:20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb...
#     institution_references:  https://ror.org/02h2x0161
# ============================================================
# depth=05m  time=07-14days
# https://data.geomar.de/thredds/dodsC/20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb23190/submission/040_connectivity_analysis_05m/040_connectivity_analysis_05m_07-14days.nc
# ============================================================
# <xarray.Dataset> Size: 11GB
# Dimensions:              (hex0: 8364, hex1: 8397, corner: 7, month: 5, year: 4)
# Coordinates:
#   * hex0                 (hex0) |S64 535kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex0             (hex0) float64 67kB ...
#     lat_hex0             (hex0) float64 67kB ...
#     hex_label            (hex0) |S64 535kB ...
#   * hex1                 (hex1) |S64 537kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex1             (hex1) float64 67kB ...
#     lat_hex1             (hex1) float64 67kB ...
#   * month                (month) float64 40B 0.0 1.0 2.0 3.0 4.0
#   * year                 (year) float64 32B 0.0 1.0 2.0 3.0
# Dimensions without coordinates: corner
# Data variables: (12/29)
#     aqc_count_hex0       (hex0) float64 67kB ...
#     rst_count_hex0       (hex0) float64 67kB ...
#     pop_count_hex0       (hex0) float64 67kB ...
#     dss_count_hex0       (hex0) float64 67kB ...
#     hly_count_hex0       (hex0) float64 67kB ...
#     his_count_hex0       (hex0) float64 67kB ...
#     ...                   ...
#     depth_std_hex1       (hex1) float32 34kB ...
#     lon_hex0_corners     (corner, hex0) float64 468kB ...
#     lat_hex0_corners     (corner, hex0) float64 468kB ...
#     lon_hex1_corners     (corner, hex1) float64 470kB ...
#     lat_hex1_corners     (corner, hex1) float64 470kB ...
#     obs                  (month, year, hex0, hex1) float64 11GB ...
# Attributes: (12/35)
#     date_created:            2025-09-04
#     date_issued:             2025-09-05
#     date_metadata_modified:  2025-09-05
#     creator_name:            Lara Schmittmann
#     creator_email:           lschmittmann@geomar.de
#     creator_id:              https://orcid.org/0009-0008-8302-6607
#     ...                      ...
#     Conventions:             CF-1.8
#     title:                   Lagrangian dispersal simulations to assess disea...
#     NCO:                     netCDF Operators version 5.1.5 (Homepage = http:...
#     history:                 Fri Sep  5 17:15:33 2025: ncatted -O -a history,...
#     id:                      hdl:20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb...
#     institution_references:  https://ror.org/02h2x0161
# ============================================================
# depth=05m  time=07-28days
# https://data.geomar.de/thredds/dodsC/20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb23190/submission/040_connectivity_analysis_05m/040_connectivity_analysis_05m_07-28days.nc
# ============================================================
# <xarray.Dataset> Size: 11GB
# Dimensions:              (hex0: 8364, hex1: 8397, corner: 7, month: 5, year: 4)
# Coordinates:
#   * hex0                 (hex0) |S64 535kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex0             (hex0) float64 67kB ...
#     lat_hex0             (hex0) float64 67kB ...
#     hex_label            (hex0) |S64 535kB ...
#   * hex1                 (hex1) |S64 537kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex1             (hex1) float64 67kB ...
#     lat_hex1             (hex1) float64 67kB ...
#   * month                (month) float64 40B 0.0 1.0 2.0 3.0 4.0
#   * year                 (year) float64 32B 0.0 1.0 2.0 3.0
# Dimensions without coordinates: corner
# Data variables: (12/29)
#     aqc_count_hex0       (hex0) float64 67kB ...
#     rst_count_hex0       (hex0) float64 67kB ...
#     pop_count_hex0       (hex0) float64 67kB ...
#     dss_count_hex0       (hex0) float64 67kB ...
#     hly_count_hex0       (hex0) float64 67kB ...
#     his_count_hex0       (hex0) float64 67kB ...
#     ...                   ...
#     depth_std_hex1       (hex1) float32 34kB ...
#     lon_hex0_corners     (corner, hex0) float64 468kB ...
#     lat_hex0_corners     (corner, hex0) float64 468kB ...
#     lon_hex1_corners     (corner, hex1) float64 470kB ...
#     lat_hex1_corners     (corner, hex1) float64 470kB ...
#     obs                  (month, year, hex0, hex1) float64 11GB ...
# Attributes: (12/35)
#     date_created:            2025-09-04
#     date_issued:             2025-09-05
#     date_metadata_modified:  2025-09-05
#     creator_name:            Lara Schmittmann
#     creator_email:           lschmittmann@geomar.de
#     creator_id:              https://orcid.org/0009-0008-8302-6607
#     ...                      ...
#     source:                  Simulated Lagrangian particle trajectories (Ocea...
#     Conventions:             CF-1.8
#     NCO:                     netCDF Operators version 5.1.5 (Homepage = http:...
#     history:                 Fri Sep  5 17:15:22 2025: ncatted -O -a history,...
#     id:                      hdl:20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb...
#     institution_references:  https://ror.org/02h2x0161
# ============================================================
# depth=10m  time=00-07days
# https://data.geomar.de/thredds/dodsC/20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb23190/submission/040_connectivity_analysis_10m/040_connectivity_analysis_10m_00-07days.nc
# ============================================================
# <xarray.Dataset> Size: 11GB
# Dimensions:              (hex0: 8302, hex1: 8338, corner: 7, month: 5, year: 4)
# Coordinates:
#   * hex0                 (hex0) |S64 531kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex0             (hex0) float64 66kB ...
#     lat_hex0             (hex0) float64 66kB ...
#     hex_label            (hex0) |S64 531kB ...
#   * hex1                 (hex1) |S64 534kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex1             (hex1) float64 67kB ...
#     lat_hex1             (hex1) float64 67kB ...
#   * month                (month) float64 40B 0.0 1.0 2.0 3.0 4.0
#   * year                 (year) float64 32B 0.0 1.0 2.0 3.0
# Dimensions without coordinates: corner
# Data variables: (12/29)
#     aqc_count_hex0       (hex0) float64 66kB ...
#     rst_count_hex0       (hex0) float64 66kB ...
#     pop_count_hex0       (hex0) float64 66kB ...
#     dss_count_hex0       (hex0) float64 66kB ...
#     hly_count_hex0       (hex0) float64 66kB ...
#     his_count_hex0       (hex0) float64 66kB ...
#     ...                   ...
#     depth_std_hex1       (hex1) float32 33kB ...
#     lon_hex0_corners     (corner, hex0) float64 465kB ...
#     lat_hex0_corners     (corner, hex0) float64 465kB ...
#     lon_hex1_corners     (corner, hex1) float64 467kB ...
#     lat_hex1_corners     (corner, hex1) float64 467kB ...
#     obs                  (month, year, hex0, hex1) float64 11GB ...
# Attributes: (12/35)
#     date_created:            2025-09-04
#     date_issued:             2025-09-05
#     date_metadata_modified:  2025-09-05
#     creator_name:            Lara Schmittmann
#     creator_email:           lschmittmann@geomar.de
#     creator_id:              https://orcid.org/0009-0008-8302-6607
#     ...                      ...
#     Conventions:             CF-1.8
#     title:                   Lagrangian dispersal simulations to assess disea...
#     NCO:                     netCDF Operators version 5.1.5 (Homepage = http:...
#     history:                 Fri Sep  5 17:18:57 2025: ncatted -O -a history,...
#     id:                      hdl:20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb...
#     institution_references:  https://ror.org/02h2x0161
# ============================================================
# depth=10m  time=07-14days
# https://data.geomar.de/thredds/dodsC/20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb23190/submission/040_connectivity_analysis_10m/040_connectivity_analysis_10m_07-14days.nc
# ============================================================
# <xarray.Dataset> Size: 11GB
# Dimensions:              (hex0: 8302, hex1: 8338, corner: 7, month: 5, year: 4)
# Coordinates:
#   * hex0                 (hex0) |S64 531kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex0             (hex0) float64 66kB ...
#     lat_hex0             (hex0) float64 66kB ...
#     hex_label            (hex0) |S64 531kB ...
#   * hex1                 (hex1) |S64 534kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex1             (hex1) float64 67kB ...
#     lat_hex1             (hex1) float64 67kB ...
#   * month                (month) float64 40B 0.0 1.0 2.0 3.0 4.0
#   * year                 (year) float64 32B 0.0 1.0 2.0 3.0
# Dimensions without coordinates: corner
# Data variables: (12/29)
#     aqc_count_hex0       (hex0) float64 66kB ...
#     rst_count_hex0       (hex0) float64 66kB ...
#     pop_count_hex0       (hex0) float64 66kB ...
#     dss_count_hex0       (hex0) float64 66kB ...
#     hly_count_hex0       (hex0) float64 66kB ...
#     his_count_hex0       (hex0) float64 66kB ...
#     ...                   ...
#     depth_std_hex1       (hex1) float32 33kB ...
#     lon_hex0_corners     (corner, hex0) float64 465kB ...
#     lat_hex0_corners     (corner, hex0) float64 465kB ...
#     lon_hex1_corners     (corner, hex1) float64 467kB ...
#     lat_hex1_corners     (corner, hex1) float64 467kB ...
#     obs                  (month, year, hex0, hex1) float64 11GB ...
# Attributes: (12/35)
#     date_created:            2025-09-04
#     date_issued:             2025-09-05
#     date_metadata_modified:  2025-09-05
#     creator_name:            Lara Schmittmann
#     creator_email:           lschmittmann@geomar.de
#     creator_id:              https://orcid.org/0009-0008-8302-6607
#     ...                      ...
#     Conventions:             CF-1.8
#     title:                   Lagrangian dispersal simulations to assess disea...
#     NCO:                     netCDF Operators version 5.1.5 (Homepage = http:...
#     history:                 Fri Sep  5 17:18:44 2025: ncatted -O -a history,...
#     id:                      hdl:20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb...
#     institution_references:  https://ror.org/02h2x0161
# ============================================================
# depth=10m  time=07-28days
# https://data.geomar.de/thredds/dodsC/20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb23190/submission/040_connectivity_analysis_10m/040_connectivity_analysis_10m_07-28days.nc
# ============================================================
# <xarray.Dataset> Size: 11GB
# Dimensions:              (hex0: 8302, hex1: 8338, corner: 7, month: 5, year: 4)
# Coordinates:
#   * hex0                 (hex0) |S64 531kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex0             (hex0) float64 66kB ...
#     lat_hex0             (hex0) float64 66kB ...
#     hex_label            (hex0) |S64 531kB ...
#   * hex1                 (hex1) |S64 534kB b'(-1, -19, 20)' ... b'(9, 9, -18)'
#     lon_hex1             (hex1) float64 67kB ...
#     lat_hex1             (hex1) float64 67kB ...
#   * month                (month) float64 40B 0.0 1.0 2.0 3.0 4.0
#   * year                 (year) float64 32B 0.0 1.0 2.0 3.0
# Dimensions without coordinates: corner
# Data variables: (12/29)
#     aqc_count_hex0       (hex0) float64 66kB ...
#     rst_count_hex0       (hex0) float64 66kB ...
#     pop_count_hex0       (hex0) float64 66kB ...
#     dss_count_hex0       (hex0) float64 66kB ...
#     hly_count_hex0       (hex0) float64 66kB ...
#     his_count_hex0       (hex0) float64 66kB ...
#     ...                   ...
#     depth_std_hex1       (hex1) float32 33kB ...
#     lon_hex0_corners     (corner, hex0) float64 465kB ...
#     lat_hex0_corners     (corner, hex0) float64 465kB ...
#     lon_hex1_corners     (corner, hex1) float64 467kB ...
#     lat_hex1_corners     (corner, hex1) float64 467kB ...
#     obs                  (month, year, hex0, hex1) float64 11GB ...
# Attributes: (12/35)
#     date_created:            2025-09-04
#     date_issued:             2025-09-05
#     date_metadata_modified:  2025-09-05
#     creator_name:            Lara Schmittmann
#     creator_email:           lschmittmann@geomar.de
#     creator_id:              https://orcid.org/0009-0008-8302-6607
#     ...                      ...
#     Conventions:             CF-1.8
#     title:                   Lagrangian dispersal simulations to assess disea...
#     NCO:                     netCDF Operators version 5.1.5 (Homepage = http:...
#     history:                 Fri Sep  5 17:18:32 2025: ncatted -O -a history,...
#     id:                      hdl:20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb...
#     institution_references:  https://ror.org/02h2x0161
# ============================================================
# depth=15m  time=00-07days
# https://data.geomar.de/thredds/dodsC/20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb23190/submission/040_connectivity_analysis_15m/040_connectivity_analysis_15m_00-07days.nc
# ============================================================
# <xarray.Dataset> Size: 11GB
# Dimensions:              (hex0: 8223, hex1: 8282, corner: 7, month: 5, year: 4)
# Coordinates:
#   * hex0                 (hex0) |S64 526kB b'(-1, -2, 3)' ... b'(9, 9, -18)'
#     lon_hex0             (hex0) float64 66kB ...
#     lat_hex0             (hex0) float64 66kB ...
#     hex_label            (hex0) |S64 526kB ...
#   * hex1                 (hex1) |S64 530kB b'(-1, -2, 3)' ... b'(9, 9, -18)'
#     lon_hex1             (hex1) float64 66kB ...
#     lat_hex1             (hex1) float64 66kB ...
#   * month                (month) float64 40B 0.0 1.0 2.0 3.0 4.0
#   * year                 (year) float64 32B 0.0 1.0 2.0 3.0
# Dimensions without coordinates: corner
# Data variables: (12/29)
#     aqc_count_hex0       (hex0) float64 66kB ...
#     rst_count_hex0       (hex0) float64 66kB ...
#     pop_count_hex0       (hex0) float64 66kB ...
#     dss_count_hex0       (hex0) float64 66kB ...
#     hly_count_hex0       (hex0) float64 66kB ...
#     his_count_hex0       (hex0) float64 66kB ...
#     ...                   ...
#     depth_std_hex1       (hex1) float32 33kB ...
#     lon_hex0_corners     (corner, hex0) float64 460kB ...
#     lat_hex0_corners     (corner, hex0) float64 460kB ...
#     lon_hex1_corners     (corner, hex1) float64 464kB ...
#     lat_hex1_corners     (corner, hex1) float64 464kB ...
#     obs                  (month, year, hex0, hex1) float64 11GB ...
# Attributes: (12/35)
#     date_created:            2025-09-04
#     date_issued:             2025-09-05
#     date_metadata_modified:  2025-09-05
#     creator_name:            Lara Schmittmann
#     creator_email:           lschmittmann@geomar.de
#     creator_id:              https://orcid.org/0009-0008-8302-6607
#     ...                      ...
#     source:                  Simulated Lagrangian particle trajectories (Ocea...
#     Conventions:             CF-1.8
#     NCO:                     netCDF Operators version 5.1.5 (Homepage = http:...
#     history:                 Fri Sep  5 17:17:30 2025: ncatted -O -a history,...
#     id:                      hdl:20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb...
#     institution_references:  https://ror.org/02h2x0161
# ============================================================
# depth=15m  time=07-14days
# https://data.geomar.de/thredds/dodsC/20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb23190/submission/040_connectivity_analysis_15m/040_connectivity_analysis_15m_07-14days.nc
# ============================================================
# <xarray.Dataset> Size: 11GB
# Dimensions:              (hex0: 8223, hex1: 8282, corner: 7, month: 5, year: 4)
# Coordinates:
#   * hex0                 (hex0) |S64 526kB b'(-1, -2, 3)' ... b'(9, 9, -18)'
#     lon_hex0             (hex0) float64 66kB ...
#     lat_hex0             (hex0) float64 66kB ...
#     hex_label            (hex0) |S64 526kB ...
#   * hex1                 (hex1) |S64 530kB b'(-1, -2, 3)' ... b'(9, 9, -18)'
#     lon_hex1             (hex1) float64 66kB ...
#     lat_hex1             (hex1) float64 66kB ...
#   * month                (month) float64 40B 0.0 1.0 2.0 3.0 4.0
#   * year                 (year) float64 32B 0.0 1.0 2.0 3.0
# Dimensions without coordinates: corner
# Data variables: (12/29)
#     aqc_count_hex0       (hex0) float64 66kB ...
#     rst_count_hex0       (hex0) float64 66kB ...
#     pop_count_hex0       (hex0) float64 66kB ...
#     dss_count_hex0       (hex0) float64 66kB ...
#     hly_count_hex0       (hex0) float64 66kB ...
#     his_count_hex0       (hex0) float64 66kB ...
#     ...                   ...
#     depth_std_hex1       (hex1) float32 33kB ...
#     lon_hex0_corners     (corner, hex0) float64 460kB ...
#     lat_hex0_corners     (corner, hex0) float64 460kB ...
#     lon_hex1_corners     (corner, hex1) float64 464kB ...
#     lat_hex1_corners     (corner, hex1) float64 464kB ...
#     obs                  (month, year, hex0, hex1) float64 11GB ...
# Attributes: (12/35)
#     date_created:            2025-09-04
#     date_issued:             2025-09-05
#     date_metadata_modified:  2025-09-05
#     creator_name:            Lara Schmittmann
#     creator_email:           lschmittmann@geomar.de
#     creator_id:              https://orcid.org/0009-0008-8302-6607
#     ...                      ...
#     source:                  Simulated Lagrangian particle trajectories (Ocea...
#     Conventions:             CF-1.8
#     NCO:                     netCDF Operators version 5.1.5 (Homepage = http:...
#     history:                 Fri Sep  5 17:17:42 2025: ncatted -O -a history,...
#     id:                      hdl:20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb...
#     institution_references:  https://ror.org/02h2x0161
# ============================================================
# depth=15m  time=07-28days
# https://data.geomar.de/thredds/dodsC/20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb23190/submission/040_connectivity_analysis_15m/040_connectivity_analysis_15m_07-28days.nc
# ============================================================
# <xarray.Dataset> Size: 11GB
# Dimensions:              (hex0: 8223, hex1: 8282, corner: 7, month: 5, year: 4)
# Coordinates:
#   * hex0                 (hex0) |S64 526kB b'(-1, -2, 3)' ... b'(9, 9, -18)'
#     lon_hex0             (hex0) float64 66kB ...
#     lat_hex0             (hex0) float64 66kB ...
#     hex_label            (hex0) |S64 526kB ...
#   * hex1                 (hex1) |S64 530kB b'(-1, -2, 3)' ... b'(9, 9, -18)'
#     lon_hex1             (hex1) float64 66kB ...
#     lat_hex1             (hex1) float64 66kB ...
#   * month                (month) float64 40B 0.0 1.0 2.0 3.0 4.0
#   * year                 (year) float64 32B 0.0 1.0 2.0 3.0
# Dimensions without coordinates: corner
# Data variables: (12/29)
#     aqc_count_hex0       (hex0) float64 66kB ...
#     rst_count_hex0       (hex0) float64 66kB ...
#     pop_count_hex0       (hex0) float64 66kB ...
#     dss_count_hex0       (hex0) float64 66kB ...
#     hly_count_hex0       (hex0) float64 66kB ...
#     his_count_hex0       (hex0) float64 66kB ...
#     ...                   ...
#     depth_std_hex1       (hex1) float32 33kB ...
#     lon_hex0_corners     (corner, hex0) float64 460kB ...
#     lat_hex0_corners     (corner, hex0) float64 460kB ...
#     lon_hex1_corners     (corner, hex1) float64 464kB ...
#     lat_hex1_corners     (corner, hex1) float64 464kB ...
#     obs                  (month, year, hex0, hex1) float64 11GB ...
# Attributes: (12/35)
#     date_created:            2025-09-04
#     date_issued:             2025-09-05
#     date_metadata_modified:  2025-09-05
#     creator_name:            Lara Schmittmann
#     creator_email:           lschmittmann@geomar.de
#     creator_id:              https://orcid.org/0009-0008-8302-6607
#     ...                      ...
#     source:                  Simulated Lagrangian particle trajectories (Ocea...
#     Conventions:             CF-1.8
#     NCO:                     netCDF Operators version 5.1.5 (Homepage = http:...
#     history:                 Fri Sep  5 17:17:52 2025: ncatted -O -a history,...
#     id:                      hdl:20.500.12085/11cc2d8f-4039-49d3-aaab-04ce0fb...
#     institution_references:  https://ror.org/02h2x0161
